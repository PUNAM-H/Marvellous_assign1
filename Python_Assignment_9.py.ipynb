# %% [markdown]
# # Q1. Write a program which contains one function named Display() that prints "Jay Ganesh" on the console.

# %%
def Display():
    print("Jay Ganesh")
dis=Display()
# Out:
# Jay Ganesh

# %%
def Display():
    print("Jay Ganesh")

Display()

# %%
def Display():
    print("Jay Ganesh")

def main():
    Display()

if __name__ == "__main__":
    main()

# %%
def Display():
    return "Jay ganesh"

def main():
    ret=Display()
    print(ret)
    
if __name__ == "__main__":
    main()
# Out:
# Jay ganesh

# %% [markdown]
# # Q2. Write a program which contains one function ChkGreater() that accepts two numbers and prints the greater number.

# %%
def ChkGreater(no1,no2):
    if no1>no2:
        print(no1, "is Greater")
    else:
        print(no2, "is Greater")
        
ChkGreater(2,3)
# Out:
# 3 is Greater

# %%
def ChkGreater(no1,no2):
    if no1>no2:
        print( no1,"is the greater number")
    else:
        print(no2," is the Greater number")

num1=int(input("Enter no1:"))
num2=int(input("Enter no2:"))

ChkGreater(num1,num2)
# Out:
# Enter no1:2
# Enter no2:3
# 3  is the Greater number

# %%
def ChkGreater(no1, no2):
    if no1 > no2:
        print(no1, "is Greater")
    else:
        print(no2, "is Greater")

def main():
    ChkGreater(10, 20)

if __name__ == "__main__":
    main()

# %%
def ChkGreater(no1,no2):
    if no1>no2:
        return no1
    else:
        return no2

def main():
    num1=int(input("Enter no1:"))
    num2=int(input("Enter no2:"))
    
    ret=ChkGreater(num1,num2)
    print("Greater number is",ret)

if __name__ == "__main__":
    main()
# Out:
# Enter no1:2
# Enter no2:3
# Greater number is 3

# %% [markdown]
# # Q3. Write a program which accepts one number and prints the square of that number.

# %%
def Squere(no):
    print("Squre is :",no*no)
    
Squere(2)
# Out:
# Squre is : 4

# %%
def Square(no):
    print("Square of",no, "is :",no*no)
    
Square(2)
# Out:
# Square of 2 is : 4

# %%
def Square(no):
    return no*no

def main():
    ret=Square(2)
    print("Square of:",no,"is",ret)  # Error :The variable no exists only inside the Square() function.
                                     # line should be: print("Square is:" , ret)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[54], line 10
#       7                                      # line should be: print("Square is:" , ret)
#       9 if __name__ == "__main__":
# ---> 10     main()
#
# Cell In[54], line 6, in main()
#       4 def main():
#       5     ret=Square(2)
# ----> 6     print("Square of:",no,"is",ret)
#
# NameError: name 'no' is not defined

# %%
def Square(no):
    print("Square is:",no*no)

def main():
    num=int(input("Enter no:"))
    ret=Square(num)

if __name__ == "__main__":
    main()
# Out:
# Enter no:2
# Square is: 4

# %%
def Square(no):
    print("Square is:",no*no)

def main():
    Square(2)

if __name__ == "__main__":
    main()
# Out:
# Square is: 4

# %%
def Square(no):
    return no*no

def main():
    ret=Square(2)
    print("Square is",ret)
    

if __name__ == "__main__":
    main()
# Out:
# Square is 4

# %%
def Square(no):
    return no * no

def main():
    num = int(input("Enter Number: "))
    ret=Square(num)
    print("Square is:", ret)

if __name__ == "__main__":
    main()
# Out:
# Enter Number: 2
# Square is: 4

# %%
def Square(no):
    print("Square is:", no * no)

def main():
    Square(2)

if __name__ == "__main__":
    main()
# Out:
# Square is: 4

# %% [markdown]
# # Q4. Write a program which accepts one number and prints the cube of that number.

# %%
def Cube(no):
    print("Cube of",no,"is",no*no*no)
    
Cube(2)
# Out:
# Cube of 2 is 8

# %%
def Cube(no):
    print("Cube is:", no * no * no)

def main():
    Cube(2)

if __name__ == "__main__":
    main()

# %%
def Cube(no):
    return no * no * no

def main():
    ret = Cube(2)
    print("Cube is:", ret)

if __name__ == "__main__":
    main()

# %%
def Cube(no):
    print("Cube is:", no ** 3)

def main():
    Cube(2)

if __name__ == "__main__":
    main()

# %%
def Cube(no):
    return no ** 3

def main():
    num = int(input("Enter Number: "))
    print("Cube is:", Cube(num))

if __name__ == "__main__":
    main()

# %% [markdown]
# # Q5. Write a program which accepts one number and checks whether it is divisible by 3 and 5.

# %%
def ChkDivisible(no):
    if (no%3 ==0 and no%5 == 0):
        print("Yes,numberis Divisible by 3 and 5")
    else:
        print("Sorry,numberis not Divisible by 3 and 5")
        
ChkDivisible(12)
# Out:
# Sorry,numberis not Divisible by 3 and 5

# %%
def Check(no):
    if no % 3 == 0 and no % 5 == 0:
        print("Divisible by 3 and 5")
    else:
        print("Not Divisible")

Check(15)

# %%
def Check(no):
    return no % 3 == 0 and no % 5 == 0

def main():
    if Check(15):
        print("Divisible by 3 and 5")
    else:
        print("Not Divisible")

if __name__ == "__main__":
    main()
# Out:
# Divisible by 3 and 5

# %%
def ChkDivisible(no):
    if no % 3 == 0 and no % 5 == 0:
        print("Divisible by 3 and 5")
    else:
        print("Not Divisible")

def main():
    ChkDivisible(15)

if __name__ == "__main__":
    main()
# Out:
# Divisible by 3 and 5

# %%
def ChkDivisible(no):
    if no % 3 == 0 and no % 5 == 0:
        print("Divisible by 3 and 5")
    else:
        print("Not Divisible")

def main():
    num = int(input("Enter Number: "))
    ChkDivisible(num)

if __name__ == "__main__":
    main()
# Out:
# Enter Number: 15
# Divisible by 3 and 5

# %%
def ChkDivisible(no):
    return no%3 == 0 and no%5 == 0 

def main():
    num=int(input("Enter the "))
    
    if ChkDivisible(num):
        print("Yes,numberis Divisible by 3 and 5")
    else:
        print("Sorry,numberis not Divisible by 3 and 5")
        
    
if __name__ == "__main__":
    main()
# Out:
# Enter the 15
# Yes,numberis Divisible by 3 and 5
